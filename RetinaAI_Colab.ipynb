# %% [markdown]
# # 🚀 RetinaAI 87% GPU Training
# 1. Ensure your Colab Extension is connected to a GPU runtime in the top right.
# 2. Run the cell below to execute the heavy 87% pipeline.

# %% [markdown]
# !python3 backend/train_gpu.py.
